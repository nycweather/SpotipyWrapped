# %%
import numpy as np 
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import time
import datetime
import requests

# %%
#Useful links
#https://developer.spotify.com/documentation/general/guides/authorization/
#https://spotipy.readthedocs.io/en/2.18.0/
#https://github.com/plamere/spotipy

# %%
spotify_client_id = '738cf140457540f592cddc50c06b7a26'
spotify_client_secret = 'bd94d538044f47d4bea8239792d83ebf'
spotify_redirect = 'http://localhost:8888/callback'
spotify_scope = 'user-top-read'

# %%
#generating request and getting authorization 
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=spotify_client_id, client_secret=spotify_client_secret, redirect_uri=spotify_redirect, scope=spotify_scope))

# %%
sp.current_user_top_artists(limit=20, offset=0, time_range='short_term')
# Out:
# {'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77SW9BnxLY8rJ0RciFqkHh'},
#    'followers': {'href': None, 'total': 10338819},
#    'genres': ['modern alternative rock', 'modern rock', 'pop', 'shimmer pop'],
#    'href': 'https://api.spotify.com/v1/artists/77SW9BnxLY8rJ0RciFqkHh',
#    'id': '77SW9BnxLY8rJ0RciFqkHh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebdf0b5ac84376a0a4b2166816',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174df0b5ac84376a0a4b2166816',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178df0b5ac84376a0a4b2166816',
#      'width': 160}],
#    'name': 'The Neighbourhood',
#    'popularity': 85,
#    'type': 'artist',
#    'uri': 'spotify:artist:77SW9BnxLY8rJ0RciFqkHh'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
# ...
